# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import censusdata


# Census & gmaps API Keys
#from config import (api_key, gkey)

#gkey ='AIzaSyAS0YHfoODq-MyD5mlpeihvsS5O_owmxbM'

api_key = "85ac64b6b5a9c0901b00329d1ef41f0c53ccfc98"


pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)
censusdata.search('acs5', 2015, 'label', 'unemploy')[160:170]


censusdata.printtable(censusdata.censustable('acs5', 2015, 'B00002'))

#censusdata.geographies(censusdata.censusgeo([('state', '13'), ('county', '121'), ('block group', '*')]), 'acs1', 2015)

#censusdata.geographies(censusdata.censusgeo([('zip code tabulation area', '*')]), 'acs1', 2015)

#censusdata.geographies(censusdata.censusgeo([('state', '13'), ('school district (elementary)', '*')]), 'acs5', 2015)

#censusdata.geographies(censusdata.censusgeo([('zip code tabulation area', '*')]), 'acs5', 2015)

#statedata = censusdata.download('acs5', 2017, censusdata.censusgeo([('zip code tabulation area', '*')]),
                                #['B01001_001E', 'B19013_001E', 'B19083_001E',
                                 #'C17002_001E', 'C17002_002E', 'C17002_003E', 'C17002_004E',
                                 #'B03002_001E', 'B03002_003E', 'B03002_004E', 'B03002_012E',])

#statedata.head()

#censusdata.download(censusdata.censustable('acs5', 2015, 'DP05'))

#censusdata.censustable('acs5', 2017, '2017')




censusdata.geographies(censusdata.censusgeo([('state', '13'), ('county', '121'), ('tract', '*')]), 'acs5', 2015)

statedata = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '13'), ('county', '121'), ('tract', '*')]),
                                ['B01001_001E', 'B19013_001E', 'B19083_001E',
                                 'C17002_001E', 'C17002_002E', 'C17002_003E', 'C17002_004E',
                                 'B03002_001E', 'B03002_003E', 'B03002_004E', 'B03002_012E',])

censusdata.geographies(censusdata.censusgeo([('state', '13'), ('county', '*')]), 'acs5', 2015)

listofcounties = [121, 089]
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B00002_001E  | B00002.  Unweighted Sample Hou | Total                                                    | int
# -------------------------------------------------------------------------------------------------------------------
# {'Appling County, Georgia': censusgeo((('state', '13'), ('county', '001'))),
#  'Atkinson County, Georgia': censusgeo((('state', '13'), ('county', '003'))),
#  'Bacon County, Georgia': censusgeo((('state', '13'), ('county', '005'))),
#  'Baker County, Georgia': censusgeo((('state', '13'), ('county', '007'))),
#  'Baldwin County, Georgia': censusgeo((('state', '13'), ('county', '009'))),
#  'Banks County, Georgia': censusgeo((('state', '13'), ('county', '011'))),
# ...

# %%
#statedata.head()

variables = pd.read_csv('data/testvariables.csv')

#censusdata.printtable(censusdata.censustable('acs5', 2017, 'B01001'))

#statedata = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '13'), ('county', '121'), ('tract', '*')]),
                                #['B00002_001E',])

statedata = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '13'), ('county', '121'), ('tract', '*')]),
                                ['B00002_001E',])

statedata['B00002_001E'].sum()
# Out:
# 27199.0

# %%
#variablestopull.head()

variablestopull = variables['Name'].tolist()
listofcounties = ['121', '089']
yearstopull = range(2012,2017,1)

atlantadata = pd.DataFrame()

for year in yearstopull:
    for county in listofcounties:

        newdata = censusdata.download('acs5', year, censusdata.censusgeo([('state', '13'), ('county', county), ('tract', '*')]),variablestopull)
        type(newdata)
        newdata['year'] = year
        #print(newdata.head())
        atlantadata.append(newdata)
        
print(atlantadata.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-5d71428bdc0b> in <module>
# ----> 1 newdata(type)
#
# TypeError: 'DataFrame' object is not callable
